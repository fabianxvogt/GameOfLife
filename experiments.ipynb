# %% [markdown]
# ### My Experiments with John Conway's Game of Life

# %%
# Out:
# (<Figure size 500x500 with 1 Axes>,
#  <matplotlib.image.AxesImage at 0x1355576e0>)

# %%
sim = sg.Simulator(board)
hist = sim.run(sg.rules.conway_classic, iters=1000)  # Save simulation history
sim.animate()
# Out:
# 2024-05-31 01:28:07.066 | INFO     | seagull.simulator:compute_statistics:128 - Computing simulation statistics...
# 2024-05-31 01:28:07.087 | INFO     | seagull.simulator:animate:183 - Rendering animation...
